# %%
import pandas as pd

# Загрузка файла
df = pd.read_csv('ml_dataset_20k.csv')

# Первые 5 строк
df.head()

# Последние 5 строк
df.tail()

# Размер датасета (строки, столбцы)
df.shape

# Названия столбцов
df.columns

# Типы данных
df.dtypes

# Общая инфо о датасете
df.info()

# Статистика (среднее, мин, макс...)
df.describe()

# Кол-во пропущенных значений
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5938 entries, 0 to 5937
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   incident_id                   5938 non-null   int64
#  1   probability                   5938 non-null   int64
#  2   is_real_incident              5938 non-null   int64
#  3   last_order_end                5938 non-null   object
#  4   after_order_start             5938 non-null   object
#  5   gap_minutes                   5938 non-null   float64
#  6   total_after_distance_km       5938 non-null   float64
#  7   max_jump_distance_km          5938 non-null   float64
#  8   mean_speed_kmh                5938 non-null   float64
#  9   median_speed_kmh              5938 non-null   float64
#  10  max_speed_kmh                 5938 non-null   float64
#  11  bearing_changes               5938 non-null   int64
# ...

# %%
# Ячейка 1
import pandas as pd
df = pd.read_csv('ml_dataset_20k.csv')

# %%
# Ячейка 2
df.head(10)
# Out:
#    incident_id  probability  is_real_incident       last_order_end  \
# 0        25744           70                 0  0001-01-01T00:00:00
# 1        25743            0                 0  0001-01-01T00:00:00
# 2        25741           70                 0  0001-01-01T00:00:00
# 3        25740           70                 0  0001-01-01T00:00:00
# 4        25739            0                 0  0001-01-01T00:00:00
# 5        25738           70                 0  0001-01-01T00:00:00
# 6        25737            0                 0  0001-01-01T00:00:00
# 7        25735            0                 0  0001-01-01T00:00:00
# 8        25734            0                 0  0001-01-01T00:00:00
# 9        25733           70                 1  0001-01-01T00:00:00
#
#             after_order_start   gap_minutes  total_after_distance_km  \
# 0  2025-03-10T01:12:28.299000 1064619432.47                     1.12
# 1  2025-03-10T18:12:55.712000 1064620452.93                     0.02
# ...

# %%
# Ячейка 3
df.describe().round(2)
# Out:
#        incident_id  probability  is_real_incident   gap_minutes  \
# count      5938.00      5938.00           5938.00       5938.00
# mean      22135.11        19.68              0.10 1064617765.00
# std        2109.70        28.83              0.30       1247.90
# min       18161.00         0.00              0.00 1064614141.22
# 25%       20486.25         0.00              0.00 1064617004.48
# 50%       22192.50         0.00              0.00 1064617591.31
# 75%       23935.75        45.00              0.00 1064618716.38
# max       25744.00        75.00              1.00 1064620506.86
#
#        total_after_distance_km  max_jump_distance_km  mean_speed_kmh  \
# count                  5938.00               5938.00         5938.00
# mean                    537.55                 63.97         5146.01
# std                    2376.51                566.37       171000.69
# min                       0.00                  0.00            0.00
# ...

# %%
# Ячейка 4
df[['probability', 'gap_minutes', 'mean_speed_kmh', 'max_speed_kmh']].head(10)
# Out:
#    probability   gap_minutes  mean_speed_kmh  max_speed_kmh
# 0           70 1064619432.47            0.08           5.09
# 1            0 1064620452.93            0.46          16.04
# 2           70 1064620356.46           37.35        2999.62
# 3           70 1064620080.01            0.90          14.36
# 4            0 1064620506.86           74.77         596.49
# 5           70 1064620498.03           10.62          47.37
# 6            0 1064620505.56            0.00           0.00
# 7            0 1064620505.90            3.21          31.78
# 8            0 1064620465.97          166.89         776.00
# 9           70 1064620356.46           39.42        2999.62

# %%
# Ячейка 5
df.isnull().sum()
# Out:
# incident_id                     0
# probability                     0
# is_real_incident                0
# last_order_end                  0
# after_order_start               0
# gap_minutes                     0
# total_after_distance_km         0
# max_jump_distance_km            0
# mean_speed_kmh                  0
# median_speed_kmh                0
# max_speed_kmh                   0
# bearing_changes                 0
# static_segments_ratio           0
# radius_from_start_m             0
# coordinate_stability_m          0
# return_count                    0
# after_order_start_hour          0
# after_track_duration_minutes    0
# bearing_changes_ratio           0
# full_stop_count                 0
# linearity                       0
# dtype: int64
